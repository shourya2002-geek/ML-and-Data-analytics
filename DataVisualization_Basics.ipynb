# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %% [markdown]
# # Downloading and Prepping Data <a id="2"></a>

# %%
df_can = pd.read_excel(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
    sheet_name='Canada by Citizenship',
    skiprows=range(20),
    skipfooter=2
    )

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
# clean up the dataset to remove unnecessary columns (eg. REG) 
df_can.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace=True)

# let's rename the columns so that they make sense
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent','RegName':'Region'}, inplace=True)

# for sake of consistency, let's also make all column labels of type string
df_can.columns = list(map(str, df_can.columns))

# set the country name as index - useful for quickly looking up countries using .loc method
df_can.set_index('Country', inplace=True)

# add total column
df_can['Total'] = df_can.sum(axis=1)

# years that we will be using in this lesson - useful for plotting later on
years = list(map(str, range(1980, 2014)))
print('data dimensions:', df_can.shape)
# Out:
# data dimensions: (195, 38)

# %% [markdown]
# # Visualizing Data using Matplotlib<a id="4"></a>

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# %% [markdown]
# # Box Plots <a id="8"></a>

# %%
df_CI= df_can.loc[['China', 'India'], years].transpose()
df_CI.head()
# Out:
# Country  China  India
# 1980      5123   8880
# 1981      6682   8670
# 1982      3308   8147
# 1983      1863   7338
# 1984      1527   5704

# %%
df_CI.plot(kind='box', figsize=(10, 7))

plt.title('Box plots of Immigrants from China and India (1980 - 2013)')
plt.ylabel('Number of Immigrants')

plt.show()

# %% [markdown]
# Question: Create a box plot to visualize the distribution of the top 15 countries (based on total immigration) grouped by the decades 1980s, 1990s, and 2000s

# %%
df_can['Country'] = df_can.index
df_top15 = df_can.sort_values(by=['Total'], ascending=False)
df_top15.drop(['Continent','Region','DevName','Total'],axis=1,inplace=True)
first_column = df_top15.pop('Country')
df_top15.insert(0, 'Country', first_column)
df_top15.reset_index(drop=True, inplace=True)
df_top15.head()
# Out:
#                                              Country   1980  ...   2012   2013
# 0                                              India   8880  ...  30933  33087
# 1                                              China   5123  ...  33024  34129
# 2  United Kingdom of Great Britain and Northern I...  22045  ...   6195   5827
# 3                                        Philippines   6051  ...  34315  29544
# 4                                           Pakistan    978  ...  11227  12603
#
# [5 rows x 35 columns]

# %%
years1 = list(map(str, range(1980, 1990)))
df_top15['1980s'] = df_top15[years1].sum(axis=1)
df_top15.drop(years1,axis=1,inplace=True)

years2 = list(map(str, range(1990, 2000)))
df_top15['1990s'] = df_top15[years2].sum(axis=1)
df_top15.drop(years2,axis=1,inplace=True)

years3 = list(map(str, range(2000, 2010)))
df_top15['2000s'] = df_top15[years3].sum(axis=1)
df_top15.drop(years3,axis=1,inplace=True)

years4 = list(map(str, range(2010, 2014)))
df_top15['2010s'] = df_top15[years4].sum(axis=1)
df_top15.drop(years4,axis=1,inplace=True)

# %%
df_top15.index = df_top15['Country'] 
df_top15.head()
# Out:
#                                                                                               Country  ...   2013
# Country                                                                                                ...
# India                                                                                           India  ...  33087
# China                                                                                           China  ...  34129
# United Kingdom of Great Britain and Northern Ir...  United Kingdom of Great Britain and Northern I...  ...   5827
# Philippines                                                                               Philippines  ...  29544
# Pakistan                                                                                     Pakistan  ...  12603
#
# [5 rows x 35 columns]

# %%
df_top15.plot(kind='box', figsize=(20, 7))

plt.title('Box plot of number of immigrants by decades')
plt.ylabel('Number of Immigrants')

plt.show()

# %% [markdown]
# # Scatter Plots <a id="10"></a>

# %% [markdown]
# Question: Create a scatter plot of the total immigration from Denmark, Norway, and Sweden to Canada from 1980 to 2013?

# %%
df_can.head()
# Out:
#                Continent           Region  ...  Total         Country
# Country                                    ...
# Afghanistan         Asia    Southern Asia  ...  58639     Afghanistan
# Albania           Europe  Southern Europe  ...  15699         Albania
# Algeria           Africa  Northern Africa  ...  69439         Algeria
# American Samoa   Oceania        Polynesia  ...      6  American Samoa
# Andorra           Europe  Southern Europe  ...     15         Andorra
#
# [5 rows x 39 columns]

# %% [markdown]
# Preparing the dataset

# %%
df_can.drop(['Continent','Region','DevName'],axis=1,inplace=True)

# %%
df_can['Country'] = df_can.index
df_three = df_can.sort_values(by=['Total'], ascending=False)
first_column = df_three.pop('Country')
df_three.insert(0, 'Country', first_column)
df_three.reset_index(drop=True, inplace=True)
df_three.head()
# Out:
#                                              Country   1980  ...   2013   Total
# 0                                              India   8880  ...  33087  691904
# 1                                              China   5123  ...  34129  659962
# 2  United Kingdom of Great Britain and Northern I...  22045  ...   5827  551500
# 3                                        Philippines   6051  ...  29544  511391
# 4                                           Pakistan    978  ...  12603  241600
#
# [5 rows x 36 columns]

# %%
select_Denmark = df_three.loc[df_three['Country'] == 'Denmark']
select_Norway = df_three.loc[df_three['Country'] == 'Norway']
select_Sweden = df_three.loc[df_three['Country'] == 'Sweden']

df_new = pd.concat([select_Denmark,select_Norway,select_Sweden])

# %%
df_new = df_new.reset_index(drop=True)
df_T = df_new.T
df_T.columns=['Denmark','Norway','Sweden']
df_T['Year'] = df_T.index
df_T.reset_index(drop=True,inplace=True)
df_T.drop([0],inplace=True)
df_T.index = df_T['Year']
df_T.drop(['Year'],axis=1,inplace=True)
df_T.head()
# Out:
#      Denmark Norway Sweden
# Year
# 1980     272    116    281
# 1981     293     77    308
# 1982     299    106    222
# 1983     106     51    176
# 1984      93     31    128

# %%
df_T['Total'] = df_T.sum(axis=1)
df_T.head()
# Out:
#      Denmark Norway Sweden  Total
# Year
# 1980     272    116    281  669.0
# 1981     293     77    308  678.0
# 1982     299    106    222  627.0
# 1983     106     51    176  333.0
# 1984      93     31    128  252.0

# %%
df_T.drop(['Denmark','Norway','Sweden'],axis=1,inplace=True)
df_T['Year'] = df_T.index
df_T.reset_index(drop=True,inplace=True)

# %%
df_T.head()
# Out:
#    Total  Year
# 0  669.0  1980
# 1  678.0  1981
# 2  627.0  1982
# 3  333.0  1983
# 4  252.0  1984

# %%
df_T.plot(kind='scatter', x='Year', y='Total', figsize=(20, 6), color='darkblue')

plt.title('Immigration from Denmark, Norway, and Sweden to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()
